# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np
from sympy import symbols
from sympy import solveset
from sympy.abc import x
from sympy import sin, cos, pi
import pylab

# %%
x = sympy.symbols('x')

# %%
f = -12*(x**4)*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
ans = solveset(f)

# %%
ans
# Out:
# ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Complexes)

# %%
x = np.arange(-10, 10, 0.1)

# %%
f = f = -12*(x**4)*np.sin(np.cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
plt.plot(x,f)
plt.grid(color='g')

# %%
f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30

Рассмотрен промежуток: (-10; 10)

Определить корни: {𝑥||𝑥∈ℂ∧−12𝑥4sin(cos(𝑥))−18𝑥3+5𝑥2+10𝑥−30=0}

Найти интервалы, на которых функция возрастает: (-7,0; -4,0); (2,5; 4,0); (7,0; 10,0)

Найти интервалы, на которых функция убывает: (-10,0; -7,0); (-4,0; -2,5); (4,0; 7,0)

Вычислить вершину: min = -7,0; max = 7.0

Определить промежутки, на котором f > 0: (-10,0; -8,0); (-5,0; -2,5); (2,5; 4,0); (8,0; 10,0)

Определить промежутки, на котором f < 0: (-8,0; -5,0); (4,0; 8,0)

Определить промежутки, на котором f = 0: (-2,5; 2,5)
